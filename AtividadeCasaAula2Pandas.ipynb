# %% [markdown]
# <a href="https://colab.research.google.com/github/lipeffl/PythonPandas/blob/main/AtividadeCasaAula2Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##Obtendo os dados:
# Ao rodarmos a célula abaixo vamos obter os dados diretamente do site:
#
# http://dados.recife.pe.gov.br/tl/dataset/relacao-de-pessoas-vacinadas-covid-19/resource/966e9c4c-df45-40d7-9c58-2f13c61a6d28

# %%
df1 = pd.read_csv('http://dados.recife.pe.gov.br/dataset/2b5ee58d-9535-4d80-ab32-f63fd475346e/resource/93f4e8c2-430f-4142-86b3-96dab4905b4e/download/casosgravescovid.csv', sep=";")

# %% [markdown]
# Utilize os comandos aprendidos em aula para os dados carregados, começando, preferencialmente, por:
# - head()
# - head(1-2)
# - tail()
# - info()
# - describe()
# - seguindo com outros aprendidos para manipulação de tratamento dos dados.

# %%
df1
# Out:
#       data_notificacao       sexo      raca etnia idade municipio_residencia  \
# 0           2020-05-30  Masculino    Branca   NaN    53               Recife
# 1           2020-06-02   Feminino     Parda   NaN     0               Recife
# 2           2020-06-02   Feminino     Parda   NaN    86               Recife
# 3           2020-06-01  Masculino    Branca   NaN    66               Recife
# 4           2020-06-02  Masculino     Preta   NaN    68               Recife
# ...                ...        ...       ...   ...   ...                  ...
# 36430       2022-06-08  Masculino  Ignorado   NaN    77               Recife
# 36431       2022-06-09  Masculino     Parda   NaN    74               Recife
# 36432       2022-06-10  Masculino     Parda   NaN    74               Recife
# 36433       2022-06-12   Feminino   Amarela   NaN    73               Recife
# 36434       2022-06-12   Feminino     Parda   NaN    66               Recife
#
# ...

# %%
df1.head() #head() para visualisar primeiras linhas do dataframe(5 primeiros)
# Out:
#   data_notificacao       sexo    raca etnia idade municipio_residencia  \
# 0       2020-05-30  Masculino  Branca   NaN    53               Recife
# 1       2020-06-02   Feminino   Parda   NaN     0               Recife
# 2       2020-06-02   Feminino   Parda   NaN    86               Recife
# 3       2020-06-01  Masculino  Branca   NaN    66               Recife
# 4       2020-06-02  Masculino   Preta   NaN    68               Recife
#
#                  bairro distrito_sanitario data_inicio_sintomas  \
# 0            SAN MARTIN                  V           2020-05-25
# 1  ALTO SANTA TEREZINHA                 II           2020-05-30
# 2            ESPINHEIRO                III           2020-06-01
# 3            CASA FORTE                III           2020-05-25
# 4        ILHA DO RETIRO                 IV           2020-05-30
#
#                                             sintomas outros_sintomas  \
# 0  Febre, Tosse, Mialgia, Alteração/perda de olfa...             NaN
# ...

# %%
df1.head(2) #duas primeiras linhas
# Out:
#   data_notificacao       sexo    raca etnia idade municipio_residencia  \
# 0       2020-05-30  Masculino  Branca   NaN    53               Recife
# 1       2020-06-02   Feminino   Parda   NaN     0               Recife
#
#                  bairro distrito_sanitario data_inicio_sintomas  \
# 0            SAN MARTIN                  V           2020-05-25
# 1  ALTO SANTA TEREZINHA                 II           2020-05-30
#
#                                             sintomas outros_sintomas  \
# 0  Febre, Tosse, Mialgia, Alteração/perda de olfa...             NaN
# 1          Febre, Tosse, Dispneia, Saturação O2 < 95             NaN
#
#   doencas_preexistentes outras_doencas_preexistentes  profissional_saude  \
# 0                   NaN                           NaN                NaN
# 1                   NaN                           NaN                NaN
#
#   categoria_profissional classificacao_final               evolucao data_obito
# ...

# %%
df1.tail() #para visualisar ultiams linhas do dataframe
# Out:
#       data_notificacao       sexo      raca etnia idade municipio_residencia  \
# 36430       2022-06-08  Masculino  Ignorado   NaN    77               Recife
# 36431       2022-06-09  Masculino     Parda   NaN    74               Recife
# 36432       2022-06-10  Masculino     Parda   NaN    74               Recife
# 36433       2022-06-12   Feminino   Amarela   NaN    73               Recife
# 36434       2022-06-12   Feminino     Parda   NaN    66               Recife
#
#                    bairro distrito_sanitario data_inicio_sintomas  \
# 36430  BREJO DA GUABIRABA                VII           2022-06-06
# 36431     NOVA DESCOBERTA                VII           2022-06-06
# 36432            BEBERIBE                 II           2022-06-03
# 36433     ENGENHO DO MEIO                 IV           2022-06-11
# 36434          BOA VIAGEM                 VI           2022-06-07
#
#                                                 sintomas outros_sintomas  \
# ...

# %%
df1.tail(15)   #pedindo as 15 ultimas linhas do dataframe)
# Out:
#       data_notificacao       sexo      raca etnia    idade  \
# 36420       2022-05-26  Masculino  Ignorado   NaN       65
# 36421       2022-05-04  Masculino     Parda   NaN        2
# 36422       2022-05-04  Masculino  Ignorado   NaN       31
# 36423       2022-05-02   Feminino    Branca   NaN       66
# 36424       2022-05-31  Masculino     Parda   NaN    1 mês
# 36425       2022-06-05   Feminino  Ignorado   NaN       72
# 36426       2022-06-05   Feminino  Ignorado   NaN       69
# 36427       2022-06-01  Masculino     Parda   NaN    1 mês
# 36428       2022-06-08  Masculino     Parda   NaN  3 meses
# 36429       2022-06-08  Masculino    Branca   NaN        1
# 36430       2022-06-08  Masculino  Ignorado   NaN       77
# 36431       2022-06-09  Masculino     Parda   NaN       74
# 36432       2022-06-10  Masculino     Parda   NaN       74
# 36433       2022-06-12   Feminino   Amarela   NaN       73
# 36434       2022-06-12   Feminino     Parda   NaN       66
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36435 entries, 0 to 36434
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   data_notificacao               36435 non-null  object
#  1   sexo                           36435 non-null  object
#  2   raca                           30106 non-null  object
#  3   etnia                          4 non-null      object
#  4   idade                          36435 non-null  object
#  5   municipio_residencia           36435 non-null  object
#  6   bairro                         36435 non-null  object
#  7   distrito_sanitario             36435 non-null  object
#  8   data_inicio_sintomas           36435 non-null  object
#  9   sintomas                       34477 non-null  object
#  10  outros_sintomas                5974 non-null   object
#  11  doencas_preexistentes          13698 non-null  object
# ...

# %%
df1.describe()
# Out:
#        data_notificacao      sexo   raca     etnia  idade  \
# count             36435     36435  30106         4  36435
# unique              836         3      6         1    127
# top          2020-04-23  Feminino  Parda  Ignorado     57
# freq                464     18643  15040         4    646
#
#        municipio_residencia      bairro distrito_sanitario  \
# count                 36435       36435              36435
# unique                    3         106                 10
# top                  Recife  BOA VIAGEM                 IV
# freq                  36433        2972               6392
#
#        data_inicio_sintomas                                   sintomas  \
# count                 36435                                      34477
# unique                  850                                       3440
# top              2020-04-20  Febre, Tosse, Dispneia, Saturação O2 < 95
# freq                    359                                       2535
#
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.shape #diznedo o tamanho da tabela
# Out:
# (36435, 18)

# %%
df1.values #visualizando valores
# Out:
# array([['2020-05-30', 'Masculino', 'Branca', ..., 'DESCARTADO',
#         'ISOLAMENTO DOMICILIAR', nan],
#        ['2020-06-02', 'Feminino', 'Parda', ..., 'INCONCLUSIVO',
#         'ISOLAMENTO DOMICILIAR', nan],
#        ['2020-06-02', 'Feminino', 'Parda', ..., 'DESCARTADO',
#         'INTERNADO LEITO DE ISOLAMENTO', nan],
#        ...,
#        ['2022-06-10', 'Masculino', 'Parda', ..., 'EM ANÁLISE',
#         'INTERNADO LEITO DE ISOLAMENTO', nan],
#        ['2022-06-12', 'Feminino', 'Amarela', ..., 'EM ANÁLISE',
#         'INTERNADO UTI', nan],
#        ['2022-06-12', 'Feminino', 'Parda', ..., 'EM ANÁLISE',
#         'INTERNADO UTI', nan]], dtype=object)

# %%
df1.index #informação sobre index
# Out:
# RangeIndex(start=0, stop=36435, step=1)

# %%
df1.isnull() #mostrando valores nulos
# Out:
#        data_notificacao   sexo   raca  etnia  idade  municipio_residencia  \
# 0                 False  False  False   True  False                 False
# 1                 False  False  False   True  False                 False
# 2                 False  False  False   True  False                 False
# 3                 False  False  False   True  False                 False
# 4                 False  False  False   True  False                 False
# ...                 ...    ...    ...    ...    ...                   ...
# 36430             False  False  False   True  False                 False
# 36431             False  False  False   True  False                 False
# 36432             False  False  False   True  False                 False
# 36433             False  False  False   True  False                 False
# 36434             False  False  False   True  False                 False
#
#        bairro  distrito_sanitario  data_inicio_sintomas  sintomas  \
# ...

# %%
#total de valores nulos
df1.isnull().sum()
# Out:
# data_notificacao                     0
# sexo                                 0
# raca                              6329
# etnia                            36431
# idade                                0
# municipio_residencia                 0
# bairro                               0
# distrito_sanitario                   0
# data_inicio_sintomas                 0
# sintomas                          1958
# outros_sintomas                  30461
# doencas_preexistentes            22737
# outras_doencas_preexistentes     28628
# profissional_saude                9097
# categoria_profissional           33521
# classificacao_final                  0
# evolucao                           977
# data_obito                       27091
# dtype: int64

# %%
df1.fillna #filtrar not a number
# Out:
# <bound method DataFrame.fillna of       data_notificacao       sexo      raca etnia idade municipio_residencia  \
# 0           2020-05-30  Masculino    Branca   NaN    53               Recife
# 1           2020-06-02   Feminino     Parda   NaN     0               Recife
# 2           2020-06-02   Feminino     Parda   NaN    86               Recife
# 3           2020-06-01  Masculino    Branca   NaN    66               Recife
# 4           2020-06-02  Masculino     Preta   NaN    68               Recife
# ...                ...        ...       ...   ...   ...                  ...
# 36430       2022-06-08  Masculino  Ignorado   NaN    77               Recife
# 36431       2022-06-09  Masculino     Parda   NaN    74               Recife
# 36432       2022-06-10  Masculino     Parda   NaN    74               Recife
# 36433       2022-06-12   Feminino   Amarela   NaN    73               Recife
# 36434       2022-06-12   Feminino     Parda   NaN    66               Recife
#
# ...

# %%
df2 = df1.fillna(df1.mean()) #substituindo valores nan pela media de valroes
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#       data_notificacao       sexo      raca etnia idade municipio_residencia  \
# 0           2020-05-30  Masculino    Branca   NaN    53               Recife
# 1           2020-06-02   Feminino     Parda   NaN     0               Recife
# 2           2020-06-02   Feminino     Parda   NaN    86               Recife
# 3           2020-06-01  Masculino    Branca   NaN    66               Recife
# 4           2020-06-02  Masculino     Preta   NaN    68               Recife
# ...                ...        ...       ...   ...   ...                  ...
# 36430       2022-06-08  Masculino  Ignorado   NaN    77               Recife
# ...

# %%
dfcopia = df2.copy() #criando copia do dataframe

# %%
df1.dropna(inplace = True) #deletando not a number onde for verdadeiro
df1
# Out:
# Empty DataFrame
# Columns: [data_notificacao, sexo, raca, etnia, idade, municipio_residencia, bairro, distrito_sanitario, data_inicio_sintomas, sintomas, outros_sintomas, doencas_preexistentes, outras_doencas_preexistentes , profissional_saude, categoria_profissional, classificacao_final, evolucao, data_obito]
# Index: []

# %%
df2 #relembrando df2
# Out:
#       data_notificacao       sexo      raca etnia idade municipio_residencia  \
# 0           2020-05-30  Masculino    Branca   NaN    53               Recife
# 1           2020-06-02   Feminino     Parda   NaN     0               Recife
# 2           2020-06-02   Feminino     Parda   NaN    86               Recife
# 3           2020-06-01  Masculino    Branca   NaN    66               Recife
# 4           2020-06-02  Masculino     Preta   NaN    68               Recife
# ...                ...        ...       ...   ...   ...                  ...
# 36430       2022-06-08  Masculino  Ignorado   NaN    77               Recife
# 36431       2022-06-09  Masculino     Parda   NaN    74               Recife
# 36432       2022-06-10  Masculino     Parda   NaN    74               Recife
# 36433       2022-06-12   Feminino   Amarela   NaN    73               Recife
# 36434       2022-06-12   Feminino     Parda   NaN    66               Recife
#
# ...

# %%
#df2.dropna(subset = [1], inplace = True) #não funcionou como no material de sala
#df2                                      #pois não são os memsos dados

# %%
df3 = df2.drop(columns = ['raca']) #excluindo coluna raca-'raça'
df3
# Out:
#       data_notificacao       sexo etnia idade municipio_residencia  \
# 0           2020-05-30  Masculino   NaN    53               Recife
# 1           2020-06-02   Feminino   NaN     0               Recife
# 2           2020-06-02   Feminino   NaN    86               Recife
# 3           2020-06-01  Masculino   NaN    66               Recife
# 4           2020-06-02  Masculino   NaN    68               Recife
# ...                ...        ...   ...   ...                  ...
# 36430       2022-06-08  Masculino   NaN    77               Recife
# 36431       2022-06-09  Masculino   NaN    74               Recife
# 36432       2022-06-10  Masculino   NaN    74               Recife
# 36433       2022-06-12   Feminino   NaN    73               Recife
# 36434       2022-06-12   Feminino   NaN    66               Recife
#
#                      bairro distrito_sanitario data_inicio_sintomas  \
# 0                SAN MARTIN                  V           2020-05-25
# ...

# %%
#deletando uma linha inteira
df4 = df3.drop(index = [2]) #indice 2 deletado 
df4
# Out:
#       data_notificacao       sexo etnia idade municipio_residencia  \
# 0           2020-05-30  Masculino   NaN    53               Recife
# 1           2020-06-02   Feminino   NaN     0               Recife
# 3           2020-06-01  Masculino   NaN    66               Recife
# 4           2020-06-02  Masculino   NaN    68               Recife
# 5           2020-06-02  Masculino   NaN    93               Recife
# ...                ...        ...   ...   ...                  ...
# 36430       2022-06-08  Masculino   NaN    77               Recife
# 36431       2022-06-09  Masculino   NaN    74               Recife
# 36432       2022-06-10  Masculino   NaN    74               Recife
# 36433       2022-06-12   Feminino   NaN    73               Recife
# 36434       2022-06-12   Feminino   NaN    66               Recife
#
#                      bairro distrito_sanitario data_inicio_sintomas  \
# 0                SAN MARTIN                  V           2020-05-25
# ...

# %%
df2.bairro.unique() #sabendo os valores de uma coluna
# Out:
# array(['SAN MARTIN', 'ALTO SANTA TEREZINHA', 'ESPINHEIRO', 'CASA FORTE',
#        'ILHA DO RETIRO', 'CORREGO DO JENIPAPO', 'NOVA DESCOBERTA',
#        'ILHA JOANA BEZERRA', 'ENGENHO DO MEIO', 'CAMPINA DO BARRETO',
#        'CORDEIRO', 'PEIXINHOS', 'GRACAS', 'LINHA DO TIRO', 'VARZEA',
#        'AREIAS', 'IBURA', 'ARRUDA', 'BEBERIBE', 'COHAB', 'SANTO AMARO',
#        'MANGUEIRA', 'ALTO DO MANDU', 'IMBIRIBEIRA', 'AGUA FRIA',
#        'AFOGADOS', 'CAMPO GRANDE', 'IPUTINGA', 'DOIS UNIDOS',
#        'JARDIM SAO PAULO', 'TORROES', 'GUABIRABA', 'SANCHO',
#        'CASA AMARELA', 'PARNAMIRIM', 'BOA VIAGEM', 'DERBY', 'IGN',
#        'TORRE', 'BOMBA DO HEMETERIO', 'MANGABEIRA', 'BOA VISTA',
#        'MADALENA', 'TAMARINEIRA', 'MONTEIRO', 'POCO', 'SAO JOSE',
#        'PASSARINHO', 'JORDAO', 'CURADO', 'BARRO', 'ENCRUZILHADA',
#        'VASCO DA GAMA', 'ALTO JOSE BONIFACIO', 'FUNDAO',
#        'BRASILIA TEIMOSA', 'TEJIPIO', 'COQUEIRAL', 'MUSTARDINHA',
# ...

# %%
df2.columns.unique() #para todas as colunas
# Out:
# Index(['data_notificacao', 'sexo', 'raca', 'etnia', 'idade',
#        'municipio_residencia', 'bairro', 'distrito_sanitario',
#        'data_inicio_sintomas', 'sintomas', 'outros_sintomas',
#        'doencas_preexistentes', 'outras_doencas_preexistentes ',
#        'profissional_saude', 'categoria_profissional', 'classificacao_final',
#        'evolucao', 'data_obito'],
#       dtype='object')

# %%
print(df2.columns.unique()) #dando o print, porém qual seria diferença?
# Out:
# Index(['data_notificacao', 'sexo', 'raca', 'etnia', 'idade',
#        'municipio_residencia', 'bairro', 'distrito_sanitario',
#        'data_inicio_sintomas', 'sintomas', 'outros_sintomas',
#        'doencas_preexistentes', 'outras_doencas_preexistentes ',
#        'profissional_saude', 'categoria_profissional', 'classificacao_final',
#        'evolucao', 'data_obito'],
#       dtype='object')

# %%
df2.index.unique() #para todo o indice
# Out:
# RangeIndex(start=0, stop=36435, step=1)

# %%
dfcopia.sort_values(by = 'data_notificacao') #usando sort para ordenar 
                                          #de acordo com a coluna data-notificação
# Out:
#       data_notificacao       sexo      raca etnia    idade  \
# 3268        2020-02-26  Masculino       NaN   NaN       41
# 34596       2020-02-26  Masculino       NaN   NaN       32
# 10764       2020-02-27   Feminino       NaN   NaN       25
# 3269        2020-02-27  Masculino       NaN   NaN       32
# 27336       2020-02-27   Feminino       NaN   NaN       30
# ...                ...        ...       ...   ...      ...
# 24111       2022-06-12   Feminino     Parda   NaN  0 meses
# 12090       2022-06-12  Masculino     Parda   NaN       64
# 36434       2022-06-12   Feminino     Parda   NaN       66
# 28325       2022-06-13  Masculino     Parda   NaN  3 meses
# 28324       2022-06-13  Masculino  Ignorado   NaN       64
#
#       municipio_residencia       bairro distrito_sanitario  \
# 3268                Recife   BOA VIAGEM                 VI
# 34596               Recife  IMBIRIBEIRA                 VI
# 10764               Recife  TAMARINEIRA                III
# ...

# %%
dfcopia.rename(columns = {'municipio_residencia': 'cidade'}, inplace = True)
dfcopia
# Out:
#       data_notificacao       sexo      raca etnia idade  cidade  \
# 0           2020-05-30  Masculino    Branca   NaN    53  Recife
# 1           2020-06-02   Feminino     Parda   NaN     0  Recife
# 2           2020-06-02   Feminino     Parda   NaN    86  Recife
# 3           2020-06-01  Masculino    Branca   NaN    66  Recife
# 4           2020-06-02  Masculino     Preta   NaN    68  Recife
# ...                ...        ...       ...   ...   ...     ...
# 36430       2022-06-08  Masculino  Ignorado   NaN    77  Recife
# 36431       2022-06-09  Masculino     Parda   NaN    74  Recife
# 36432       2022-06-10  Masculino     Parda   NaN    74  Recife
# 36433       2022-06-12   Feminino   Amarela   NaN    73  Recife
# 36434       2022-06-12   Feminino     Parda   NaN    66  Recife
#
#                      bairro distrito_sanitario data_inicio_sintomas  \
# 0                SAN MARTIN                  V           2020-05-25
# ...

# %%
dfcopia = pd.DataFrame(dfcopia) #armazenando
dfcopia
# Out:
#       data_notificacao       sexo      raca etnia idade  cidade  \
# 0           2020-05-30  Masculino    Branca   NaN    53  Recife
# 1           2020-06-02   Feminino     Parda   NaN     0  Recife
# 2           2020-06-02   Feminino     Parda   NaN    86  Recife
# 3           2020-06-01  Masculino    Branca   NaN    66  Recife
# 4           2020-06-02  Masculino     Preta   NaN    68  Recife
# ...                ...        ...       ...   ...   ...     ...
# 36430       2022-06-08  Masculino  Ignorado   NaN    77  Recife
# 36431       2022-06-09  Masculino     Parda   NaN    74  Recife
# 36432       2022-06-10  Masculino     Parda   NaN    74  Recife
# 36433       2022-06-12   Feminino   Amarela   NaN    73  Recife
# 36434       2022-06-12   Feminino     Parda   NaN    66  Recife
#
#                      bairro distrito_sanitario data_inicio_sintomas  \
# 0                SAN MARTIN                  V           2020-05-25
# ...

# %%
#renomeando colunas manualmente
dfcopia.rename(columns = {'data_notificacao': 'cadastramento', 'sexo': 'sexo_biologico',
 'raca': 'fenotipo_racial', 'etnia': 'identidade_cultural', 'cidade': 'local_onde_reside',
 'bairro': 'comunidade', 'distrito_sanitario': 'unidade_sanitaria', 'data_inicio_sintomas': 'inicio_dos_sintomas',
 'sintomas': 'sintomatologia', 'outros_sintomas': 'sintomas_suspeitos', 'doencas_preexistentes': 'doencas_anteriores', 
 'outras_doencas_preexistentes': 'historico_doencas', 'profissional_saude': 'trabalhador_saude', 'categoria_profissional': 'classe_profissional',
 'classificacao_final': 'conclusao', 'evolucao': 'desenvolvimento', 'data_obito': 'morte'}, inplace = True)
dfcopia
# Out:
#       cadastramento sexo_biologico fenotipo_racial identidade_cultural idade  \
# 0        2020-05-30      Masculino          Branca                 NaN    53
# 1        2020-06-02       Feminino           Parda                 NaN     0
# 2        2020-06-02       Feminino           Parda                 NaN    86
# 3        2020-06-01      Masculino          Branca                 NaN    66
# 4        2020-06-02      Masculino           Preta                 NaN    68
# ...             ...            ...             ...                 ...   ...
# 36430    2022-06-08      Masculino        Ignorado                 NaN    77
# 36431    2022-06-09      Masculino           Parda                 NaN    74
# 36432    2022-06-10      Masculino           Parda                 NaN    74
# 36433    2022-06-12       Feminino         Amarela                 NaN    73
# 36434    2022-06-12       Feminino           Parda                 NaN    66
#
# ...

# %%
dfcopia = pd.DataFrame(dfcopia) #armazenando
dfcopia
# Out:
#       cadastramento sexo_biologico fenotipo_racial identidade_cultural idade  \
# 0        2020-05-30      Masculino          Branca                 NaN    53
# 1        2020-06-02       Feminino           Parda                 NaN     0
# 2        2020-06-02       Feminino           Parda                 NaN    86
# 3        2020-06-01      Masculino          Branca                 NaN    66
# 4        2020-06-02      Masculino           Preta                 NaN    68
# ...             ...            ...             ...                 ...   ...
# 36430    2022-06-08      Masculino        Ignorado                 NaN    77
# 36431    2022-06-09      Masculino           Parda                 NaN    74
# 36432    2022-06-10      Masculino           Parda                 NaN    74
# 36433    2022-06-12       Feminino         Amarela                 NaN    73
# 36434    2022-06-12       Feminino           Parda                 NaN    66
#
# ...

# %%
dfcopia.dropna(subset = ['identidade_cultural'], inplace = True)
dfcopia = pd.DataFrame(dfcopia) #armazenando
dfcopia
# Out:
#       cadastramento sexo_biologico fenotipo_racial identidade_cultural  \
# 1583     2021-03-09      Masculino        Indígena            Ignorado
# 3489     2021-08-02       Feminino        Indígena            Ignorado
# 18148    2022-02-16       Feminino        Indígena            Ignorado
# 35571    2021-05-05       Feminino        Indígena            Ignorado
#
#          idade local_onde_reside        comunidade unidade_sanitaria  \
# 1583        65            Recife     VASCO DA GAMA               VII
# 3489   1 meses            Recife  SITIO DOS PINTOS               III
# 18148        1            Recife          IPUTINGA                IV
# 35571       62            Recife        ESPINHEIRO               III
#
#       inicio_dos_sintomas                                     sintomatologia  \
# 1583           2021-03-02  Dispneia, Desconforto respiratório / aperto to...
# 3489           2021-07-30                   Febre, Tosse, Dispneia, Diarreia
# ...

# %%
dfcopia.dropna(subset = ['sintomas_suspeitos'], inplace = True)
dfcopia = pd.DataFrame(dfcopia) #armazenando
dfcopia
# Out:
#       cadastramento sexo_biologico fenotipo_racial identidade_cultural idade  \
# 1583     2021-03-09      Masculino        Indígena            Ignorado    65
# 18148    2022-02-16       Feminino        Indígena            Ignorado     1
#
#       local_onde_reside     comunidade unidade_sanitaria inicio_dos_sintomas  \
# 1583             Recife  VASCO DA GAMA               VII          2021-03-02
# 18148            Recife       IPUTINGA                IV          2022-02-11
#
#                                           sintomatologia  \
# 1583   Dispneia, Desconforto respiratório / aperto to...
# 18148  Febre, Tosse, Dispneia, Desconforto respiratór...
#
#                                       sintomas_suspeitos  \
# 1583   HIPERGLICEMIA, DORES NO PEITO, INCONTINENCIA U...
# 18148                                         SONOLENCIA
#
#                               doencas_anteriores  \
# 1583   Doenças Cardíacas ou Vasculares, Diabetes
# ...

# %%
dfcopia.dropna(subset = ['doencas_anteriores'], inplace = True)
dfcopia = pd.DataFrame(dfcopia)
dfcopia
# Out:
#      cadastramento sexo_biologico fenotipo_racial identidade_cultural idade  \
# 1583    2021-03-09      Masculino        Indígena            Ignorado    65
#
#      local_onde_reside     comunidade unidade_sanitaria inicio_dos_sintomas  \
# 1583            Recife  VASCO DA GAMA               VII          2021-03-02
#
#                                          sintomatologia  \
# 1583  Dispneia, Desconforto respiratório / aperto to...
#
#                                      sintomas_suspeitos  \
# 1583  HIPERGLICEMIA, DORES NO PEITO, INCONTINENCIA U...
#
#                              doencas_anteriores outras_doencas_preexistentes   \
# 1583  Doenças Cardíacas ou Vasculares, Diabetes                           NaN
#
#      trabalhador_saude classe_profissional   conclusao desenvolvimento  \
# 1583               NÃO                 NaN  DESCARTADO           ÓBITO
#
#            morte
# 1583  2021-03-09

# %%
#dfcopia.dropna(subset = ['outras_doencas_preexistentes'], inplace = True) 
#dfcopia = pd.DataFrame(dfcopia)   ##outras_doencas_preexistente - não foi possivel renomear nem excluir o NAN
#dfcopia

# %%
dfcopia.dropna(subset = ['classe_profissional'], inplace = True)
dfcopia = pd.DataFrame(dfcopia)
dfcopia
# Out:
# Empty DataFrame
# Columns: [cadastramento, sexo_biologico, fenotipo_racial, identidade_cultural, idade, local_onde_reside, comunidade, unidade_sanitaria, inicio_dos_sintomas, sintomatologia, sintomas_suspeitos, doencas_anteriores, outras_doencas_preexistentes , trabalhador_saude, classe_profissional, conclusao, desenvolvimento, morte]
# Index: []

# %%
dfcopia.reset_index()
# Out:
# Empty DataFrame
# Columns: [index, cadastramento, sexo_biologico, fenotipo_racial, identidade_cultural, idade, local_onde_reside, comunidade, unidade_sanitaria, inicio_dos_sintomas, sintomatologia, sintomas_suspeitos, doencas_anteriores, outras_doencas_preexistentes , trabalhador_saude, classe_profissional, conclusao, desenvolvimento, morte]
# Index: []

# %%
dfcopia.columns.value_counts().sum()
# Out:
# 18

# %%
dfcopia.index.value_counts().sum()
# Out:
# 0
